# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Bidirectional, Dropout
from tensorflow.keras.optimizers import Adam

data = pd.read_excel('Megamillions.xlsx')
next_date = input("Enter the date for the next prediction (MM/DD/YYYY): ")

sequence_length = 7

data_copy = data.copy()
data.drop(['Date'], axis=1, inplace=True)

feature_count = data.shape[1]

training_data = data.copy()

training_rows = training_data.values.shape[0]
training_samples = np.empty([training_rows - sequence_length, sequence_length, feature_count], dtype=float)
training_labels = np.empty([training_rows - sequence_length, feature_count], dtype=float)
for i in range(0, training_rows - sequence_length):
    training_samples[i] = training_data.iloc[i: i + sequence_length, 0: feature_count]
    training_labels[i] = training_data.iloc[i + sequence_length: i + sequence_length + 1, 0: feature_count]

scaler = StandardScaler()
scaled_data = scaler.fit_transform(training_data.values)
scaled_training_samples = pd.DataFrame(data=scaled_data, index=training_data.index)

x_train = np.empty([training_rows - sequence_length, sequence_length, feature_count], dtype=float)
y_train = np.empty([training_rows - sequence_length, feature_count], dtype=float)

for i in range(0, training_rows - sequence_length):
    x_train[i] = scaled_training_samples.iloc[i: i + sequence_length, 0: feature_count]
    y_train[i] = scaled_training_samples.iloc[i + sequence_length: i + sequence_length + 1, 0: feature_count]

rnn_model = Sequential()
rnn_model.add(Bidirectional(LSTM(240, input_shape=(sequence_length, feature_count), return_sequences=True)))
rnn_model.add(Dropout(0.2))
rnn_model.add(Bidirectional(LSTM(240, input_shape=(sequence_length, feature_count), return_sequences=True)))
rnn_model.add(Dropout(0.2))
rnn_model.add(Bidirectional(LSTM(240, input_shape=(sequence_length, feature_count), return_sequences=True)))
rnn_model.add(Bidirectional(LSTM(240, input_shape=(sequence_length, feature_count), return_sequences=False)))
rnn_model.add(Dropout(0.2))
rnn_model.add(Dense(70))
rnn_model.add(Dense(feature_count))

rnn_model.compile(optimizer=Adam(learning_rate=0.0001), loss='mse', metrics=['accuracy'])

rnn_model.fit(x=x_train, y=y_train, batch_size=100, epochs=1200, verbose=2)

print('-' * 40)
print('Prediction vs. Ground Truth without rounding up or down')
for i in range(1, 10):
    test_data = data_copy.copy()
    test_data = test_data.tail((sequence_length + 10 - i))
    test_data = test_data.head((sequence_length + 1))
    test_date = data_copy.iloc[(test_data.tail().index[-1])]['Date']
    test_input = test_data.head((sequence_length))
    test_input.drop(['Date'], axis=1, inplace=True)
    test_input = np.array(test_input)
    x_test = scaler.transform(test_input)
    y_test_pred = rnn_model.predict(np.array([x_test]))
    test_data.drop(['Date'], axis=1, inplace=True)
    y_test_true = test_data.tail(1)
    print('Drawing Date:', test_date)
    print('Prediction:\t', scaler.inverse_transform(y_test_pred).astype(int)[0])
    print('Ground Truth:\t', np.array(y_test_true)[0])
    print('-' * 40)

print('-' * 40)
print('Prediction vs. Ground Truth with rounding up')
for i in range(1, 10):
    test_data = data_copy.copy()
    test_data = test_data.tail((sequence_length + 10 - i))
    test_data = test_data.head((sequence_length + 1))
    test_date = data_copy.iloc[(test_data.tail().index[-1])]['Date']
    test_input = test_data.head((sequence_length))
    test_input.drop(['Date'], axis=1, inplace=True)
    test_input = np.array(test_input)
    x_test = scaler.transform(test_input)
    y_test_pred = rnn_model.predict(np.array([x_test]))
    test_data.drop(['Date'], axis=1, inplace=True)
    y_test_true = test_data.tail(1)
    print('Drawing Date:', test_date)
    print('Prediction:\t', scaler.inverse_transform(y_test_pred).astype(int)[0] + 1)
    print('Ground Truth:\t', np.array(y_test_true)[0])
    print('-' * 40)



print('-' * 40)
print('Predict the Future Drawing')
future_data = data.copy()
future_data = future_data.tail((sequence_length))
future_data = np.array(future_data)
x_future = scaler.transform(future_data)
y_future_pred = rnn_model.predict(np.array([x_future]))
print('Drawing Date:', next_date)
print('Prediction without rounding up or down:\t', scaler.inverse_transform(y_future_pred).astype(int)[0])
print('Prediction with rounding up           :\t', scaler.inverse_transform(y_future_pred).astype(int)[0] + 1)
print('Prediction with rounding down         :\t', scaler.inverse_transform(y_future_pred).astype(int)[0] - 1)
print('-' * 40)
# Out:
# Epoch 1/1200
# 22/22 - 29s - loss: 0.9147 - accuracy: 0.3728 - 29s/epoch - 1s/step
# Epoch 2/1200
# 22/22 - 11s - loss: 0.8658 - accuracy: 0.3984 - 11s/epoch - 480ms/step
# Epoch 3/1200
# 22/22 - 11s - loss: 0.8544 - accuracy: 0.3998 - 11s/epoch - 519ms/step
# Epoch 4/1200
# 22/22 - 11s - loss: 0.8543 - accuracy: 0.3962 - 11s/epoch - 512ms/step
# Epoch 5/1200
# 22/22 - 11s - loss: 0.8509 - accuracy: 0.4003 - 11s/epoch - 514ms/step
# Epoch 6/1200
# 22/22 - 11s - loss: 0.8518 - accuracy: 0.4003 - 11s/epoch - 513ms/step
# Epoch 7/1200
# 22/22 - 11s - loss: 0.8487 - accuracy: 0.3975 - 11s/epoch - 514ms/step
# Epoch 8/1200
# 22/22 - 11s - loss: 0.8486 - accuracy: 0.3984 - 11s/epoch - 513ms/step
# Epoch 9/1200
# 22/22 - 11s - loss: 0.8480 - accuracy: 0.3984 - 11s/epoch - 511ms/step
# Epoch 10/1200
# 22/22 - 10s - loss: 0.8463 - accuracy: 0.4012 - 10s/epoch - 462ms/step
# Epoch 11/1200
# 22/22 - 11s - loss: 0.8479 - accuracy: 0.3998 - 11s/epoch - 510ms/step
# Epoch 12/1200
# 22/22 - 11s - loss: 0.8455 - accuracy: 0.3971 - 11s/epoch - 520ms/step
# Epoch 13/1200
# 22/22 - 11s - loss: 0.8451 - accuracy: 0.3994 - 11s/epoch - 512ms/step
# Epoch 14/1200
# 22/22 - 11s - loss: 0.8448 - accuracy: 0.3989 - 11s/epoch - 510ms/step
# Epoch 15/1200
# 22/22 - 11s - loss: 0.8441 - accuracy: 0.3989 - 11s/epoch - 512ms/step
# Epoch 16/1200
# 22/22 - 11s - loss: 0.8438 - accuracy: 0.3971 - 11s/epoch - 512ms/step
# Epoch 17/1200
# 22/22 - 11s - loss: 0.8434 - accuracy: 0.4003 - 11s/epoch - 510ms/step
# Epoch 18/1200
# 22/22 - 10s - loss: 0.8414 - accuracy: 0.3984 - 10s/epoch - 458ms/step
# Epoch 19/1200
# 22/22 - 11s - loss: 0.8422 - accuracy: 0.3998 - 11s/epoch - 508ms/step
# Epoch 20/1200
# 22/22 - 11s - loss: 0.8453 - accuracy: 0.3994 - 11s/epoch - 511ms/step
# Epoch 21/1200
# 22/22 - 11s - loss: 0.8409 - accuracy: 0.3975 - 11s/epoch - 509ms/step
# Epoch 22/1200
# 22/22 - 11s - loss: 0.8403 - accuracy: 0.3998 - 11s/epoch - 513ms/step
# Epoch 23/1200
# 22/22 - 11s - loss: 0.8396 - accuracy: 0.3998 - 11s/epoch - 510ms/step
# Epoch 24/1200
# 22/22 - 11s - loss: 0.8367 - accuracy: 0.4007 - 11s/epoch - 513ms/step
# Epoch 25/1200
# 22/22 - 11s - loss: 0.8373 - accuracy: 0.4012 - 11s/epoch - 506ms/step
# Epoch 26/1200
# 22/22 - 10s - loss: 0.8382 - accuracy: 0.3989 - 10s/epoch - 464ms/step
# Epoch 27/1200
# 22/22 - 11s - loss: 0.8366 - accuracy: 0.3989 - 11s/epoch - 511ms/step
# Epoch 28/1200
# 22/22 - 11s - loss: 0.8356 - accuracy: 0.3994 - 11s/epoch - 512ms/step
# Epoch 29/1200
# 22/22 - 11s - loss: 0.8361 - accuracy: 0.4003 - 11s/epoch - 511ms/step
# Epoch 30/1200
# 22/22 - 11s - loss: 0.8329 - accuracy: 0.3984 - 11s/epoch - 514ms/step
# Epoch 31/1200
# 22/22 - 11s - loss: 0.8333 - accuracy: 0.4003 - 11s/epoch - 511ms/step
# Epoch 32/1200
# 22/22 - 11s - loss: 0.8315 - accuracy: 0.4012 - 11s/epoch - 514ms/step
# Epoch 33/1200
# 22/22 - 11s - loss: 0.8345 - accuracy: 0.3994 - 11s/epoch - 496ms/step
# Epoch 34/1200
# 22/22 - 10s - loss: 0.8322 - accuracy: 0.4007 - 10s/epoch - 472ms/step
# Epoch 35/1200
# 22/22 - 11s - loss: 0.8322 - accuracy: 0.3962 - 11s/epoch - 513ms/step
# Epoch 36/1200
# 22/22 - 11s - loss: 0.8316 - accuracy: 0.3998 - 11s/epoch - 512ms/step
# Epoch 37/1200
# 22/22 - 11s - loss: 0.8300 - accuracy: 0.3994 - 11s/epoch - 512ms/step
# Epoch 38/1200
# 22/22 - 11s - loss: 0.8282 - accuracy: 0.3957 - 11s/epoch - 509ms/step
# Epoch 39/1200
# 22/22 - 11s - loss: 0.8305 - accuracy: 0.3989 - 11s/epoch - 511ms/step
# Epoch 40/1200
# 22/22 - 11s - loss: 0.8287 - accuracy: 0.3948 - 11s/epoch - 510ms/step
# Epoch 41/1200
# 22/22 - 11s - loss: 0.8277 - accuracy: 0.4026 - 11s/epoch - 480ms/step
# Epoch 42/1200
# 22/22 - 11s - loss: 0.8254 - accuracy: 0.3980 - 11s/epoch - 484ms/step
# Epoch 43/1200
# 22/22 - 11s - loss: 0.8305 - accuracy: 0.3994 - 11s/epoch - 511ms/step
# Epoch 44/1200
# 22/22 - 11s - loss: 0.8279 - accuracy: 0.4030 - 11s/epoch - 511ms/step
# Epoch 45/1200
# 22/22 - 11s - loss: 0.8236 - accuracy: 0.3962 - 11s/epoch - 512ms/step
# Epoch 46/1200
# 22/22 - 11s - loss: 0.8234 - accuracy: 0.3994 - 11s/epoch - 510ms/step
# Epoch 47/1200
# 22/22 - 11s - loss: 0.8225 - accuracy: 0.3998 - 11s/epoch - 516ms/step
# Epoch 48/1200
# 22/22 - 11s - loss: 0.8229 - accuracy: 0.3975 - 11s/epoch - 512ms/step
# Epoch 49/1200
# 22/22 - 10s - loss: 0.8222 - accuracy: 0.3980 - 10s/epoch - 472ms/step
# Epoch 50/1200
# 22/22 - 11s - loss: 0.8218 - accuracy: 0.4039 - 11s/epoch - 492ms/step
# Epoch 51/1200
# 22/22 - 11s - loss: 0.8231 - accuracy: 0.3971 - 11s/epoch - 512ms/step
# Epoch 52/1200
# 22/22 - 11s - loss: 0.8231 - accuracy: 0.3966 - 11s/epoch - 512ms/step
# Epoch 53/1200
# 22/22 - 11s - loss: 0.8227 - accuracy: 0.4003 - 11s/epoch - 514ms/step
# Epoch 54/1200
# 22/22 - 11s - loss: 0.8205 - accuracy: 0.3998 - 11s/epoch - 513ms/step
# Epoch 55/1200
# 22/22 - 11s - loss: 0.8196 - accuracy: 0.3957 - 11s/epoch - 508ms/step
# Epoch 56/1200
# 22/22 - 11s - loss: 0.8221 - accuracy: 0.4035 - 11s/epoch - 513ms/step
# Epoch 57/1200
# 22/22 - 10s - loss: 0.8229 - accuracy: 0.3984 - 10s/epoch - 463ms/step
# Epoch 58/1200
# 22/22 - 11s - loss: 0.8192 - accuracy: 0.4026 - 11s/epoch - 508ms/step
# Epoch 59/1200
# 22/22 - 11s - loss: 0.8165 - accuracy: 0.3994 - 11s/epoch - 516ms/step
# Epoch 60/1200
# 22/22 - 11s - loss: 0.8183 - accuracy: 0.4021 - 11s/epoch - 514ms/step
# Epoch 61/1200
# 22/22 - 11s - loss: 0.8167 - accuracy: 0.4021 - 11s/epoch - 518ms/step
# Epoch 62/1200
# 22/22 - 11s - loss: 0.8148 - accuracy: 0.4012 - 11s/epoch - 517ms/step
# Epoch 63/1200
# 22/22 - 12s - loss: 0.8162 - accuracy: 0.4048 - 12s/epoch - 523ms/step
# Epoch 64/1200
# 22/22 - 11s - loss: 0.8125 - accuracy: 0.4026 - 11s/epoch - 520ms/step
# Epoch 65/1200
# 22/22 - 11s - loss: 0.8112 - accuracy: 0.3957 - 11s/epoch - 494ms/step
# Epoch 66/1200
# 22/22 - 11s - loss: 0.8113 - accuracy: 0.4016 - 11s/epoch - 491ms/step
# Epoch 67/1200
# 22/22 - 11s - loss: 0.8130 - accuracy: 0.4048 - 11s/epoch - 522ms/step
# Epoch 68/1200
# 22/22 - 11s - loss: 0.8103 - accuracy: 0.4007 - 11s/epoch - 514ms/step
# Epoch 69/1200
# 22/22 - 11s - loss: 0.8079 - accuracy: 0.4053 - 11s/epoch - 512ms/step
# Epoch 70/1200
# 22/22 - 11s - loss: 0.8102 - accuracy: 0.4012 - 11s/epoch - 511ms/step
# Epoch 71/1200
# 22/22 - 11s - loss: 0.8134 - accuracy: 0.4003 - 11s/epoch - 509ms/step
# Epoch 72/1200
# 22/22 - 11s - loss: 0.8074 - accuracy: 0.4067 - 11s/epoch - 516ms/step
# Epoch 73/1200
# 22/22 - 11s - loss: 0.8060 - accuracy: 0.4007 - 11s/epoch - 492ms/step
# Epoch 74/1200
# 22/22 - 10s - loss: 0.8049 - accuracy: 0.4039 - 10s/epoch - 475ms/step
# Epoch 75/1200
# 22/22 - 11s - loss: 0.8041 - accuracy: 0.4053 - 11s/epoch - 513ms/step
# Epoch 76/1200
# 22/22 - 11s - loss: 0.8047 - accuracy: 0.4053 - 11s/epoch - 516ms/step
# Epoch 77/1200
# 22/22 - 11s - loss: 0.7997 - accuracy: 0.4081 - 11s/epoch - 513ms/step
# Epoch 78/1200
# 22/22 - 11s - loss: 0.7975 - accuracy: 0.4085 - 11s/epoch - 515ms/step
# Epoch 79/1200
# 22/22 - 11s - loss: 0.7999 - accuracy: 0.4039 - 11s/epoch - 515ms/step
# Epoch 80/1200
# 22/22 - 11s - loss: 0.7980 - accuracy: 0.4048 - 11s/epoch - 514ms/step
# Epoch 81/1200
# 22/22 - 11s - loss: 0.7988 - accuracy: 0.4085 - 11s/epoch - 493ms/step
# Epoch 82/1200
# 22/22 - 10s - loss: 0.7947 - accuracy: 0.4053 - 10s/epoch - 477ms/step
# Epoch 83/1200
# 22/22 - 11s - loss: 0.7887 - accuracy: 0.4117 - 11s/epoch - 515ms/step
# Epoch 84/1200
# 22/22 - 11s - loss: 0.7926 - accuracy: 0.4145 - 11s/epoch - 512ms/step
# Epoch 85/1200
# 22/22 - 11s - loss: 0.7907 - accuracy: 0.4053 - 11s/epoch - 510ms/step
# Epoch 86/1200
# 22/22 - 11s - loss: 0.7855 - accuracy: 0.4131 - 11s/epoch - 512ms/step
# Epoch 87/1200
# 22/22 - 11s - loss: 0.7877 - accuracy: 0.4140 - 11s/epoch - 511ms/step
# Epoch 88/1200
# 22/22 - 11s - loss: 0.7863 - accuracy: 0.4108 - 11s/epoch - 510ms/step
# Epoch 89/1200
# 22/22 - 11s - loss: 0.7864 - accuracy: 0.4103 - 11s/epoch - 480ms/step
# Epoch 90/1200
# 22/22 - 11s - loss: 0.7813 - accuracy: 0.4195 - 11s/epoch - 491ms/step
# Epoch 91/1200
# 22/22 - 11s - loss: 0.7787 - accuracy: 0.4053 - 11s/epoch - 508ms/step
# Epoch 92/1200
# 22/22 - 11s - loss: 0.7749 - accuracy: 0.4122 - 11s/epoch - 512ms/step
# Epoch 93/1200
# 22/22 - 11s - loss: 0.7742 - accuracy: 0.4158 - 11s/epoch - 511ms/step
# Epoch 94/1200
# 22/22 - 11s - loss: 0.7698 - accuracy: 0.4181 - 11s/epoch - 511ms/step
# Epoch 95/1200
# 22/22 - 11s - loss: 0.7734 - accuracy: 0.4172 - 11s/epoch - 508ms/step
# Epoch 96/1200
# 22/22 - 11s - loss: 0.7700 - accuracy: 0.4140 - 11s/epoch - 512ms/step
# Epoch 97/1200
# 22/22 - 10s - loss: 0.7688 - accuracy: 0.4158 - 10s/epoch - 470ms/step
# Epoch 98/1200
# 22/22 - 11s - loss: 0.7595 - accuracy: 0.4140 - 11s/epoch - 498ms/step
# Epoch 99/1200
# 22/22 - 11s - loss: 0.7618 - accuracy: 0.4145 - 11s/epoch - 513ms/step
# Epoch 100/1200
# 22/22 - 11s - loss: 0.7622 - accuracy: 0.4195 - 11s/epoch - 512ms/step
# Epoch 101/1200
# 22/22 - 11s - loss: 0.7599 - accuracy: 0.4167 - 11s/epoch - 514ms/step
# Epoch 102/1200
# 22/22 - 11s - loss: 0.7535 - accuracy: 0.4181 - 11s/epoch - 515ms/step
# Epoch 103/1200
# 22/22 - 11s - loss: 0.7538 - accuracy: 0.4195 - 11s/epoch - 513ms/step
# Epoch 104/1200
# 22/22 - 11s - loss: 0.7579 - accuracy: 0.4186 - 11s/epoch - 516ms/step
# Epoch 105/1200
# 22/22 - 10s - loss: 0.7513 - accuracy: 0.4126 - 10s/epoch - 470ms/step
# Epoch 106/1200
# 22/22 - 11s - loss: 0.7505 - accuracy: 0.4149 - 11s/epoch - 505ms/step
# Epoch 107/1200
# 22/22 - 11s - loss: 0.7427 - accuracy: 0.4209 - 11s/epoch - 518ms/step
# Epoch 108/1200
# 22/22 - 11s - loss: 0.7358 - accuracy: 0.4195 - 11s/epoch - 515ms/step
# Epoch 109/1200
# 22/22 - 11s - loss: 0.7330 - accuracy: 0.4236 - 11s/epoch - 513ms/step
# Epoch 110/1200
# 22/22 - 11s - loss: 0.7325 - accuracy: 0.4250 - 11s/epoch - 514ms/step
# Epoch 111/1200
# 22/22 - 11s - loss: 0.7328 - accuracy: 0.4209 - 11s/epoch - 515ms/step
# Epoch 112/1200
# 22/22 - 11s - loss: 0.7318 - accuracy: 0.4254 - 11s/epoch - 513ms/step
# Epoch 113/1200
# 22/22 - 11s - loss: 0.7256 - accuracy: 0.4209 - 11s/epoch - 478ms/step
# Epoch 114/1200
# 22/22 - 11s - loss: 0.7219 - accuracy: 0.4282 - 11s/epoch - 493ms/step
# Epoch 115/1200
# 22/22 - 11s - loss: 0.7205 - accuracy: 0.4323 - 11s/epoch - 512ms/step
# Epoch 116/1200
# 22/22 - 11s - loss: 0.7216 - accuracy: 0.4405 - 11s/epoch - 511ms/step
# Epoch 117/1200
# 22/22 - 11s - loss: 0.7187 - accuracy: 0.4273 - 11s/epoch - 513ms/step
# Epoch 118/1200
# 22/22 - 11s - loss: 0.7088 - accuracy: 0.4355 - 11s/epoch - 513ms/step
# Epoch 119/1200
# 22/22 - 11s - loss: 0.7079 - accuracy: 0.4291 - 11s/epoch - 512ms/step
# Epoch 120/1200
# 22/22 - 11s - loss: 0.7022 - accuracy: 0.4291 - 11s/epoch - 509ms/step
# Epoch 121/1200
# 22/22 - 10s - loss: 0.6945 - accuracy: 0.4296 - 10s/epoch - 466ms/step
# Epoch 122/1200
# 22/22 - 11s - loss: 0.6910 - accuracy: 0.4382 - 11s/epoch - 510ms/step
# Epoch 123/1200
# 22/22 - 11s - loss: 0.6886 - accuracy: 0.4442 - 11s/epoch - 511ms/step
# Epoch 124/1200
# 22/22 - 11s - loss: 0.6855 - accuracy: 0.4414 - 11s/epoch - 509ms/step
# Epoch 125/1200
# 22/22 - 11s - loss: 0.6774 - accuracy: 0.4428 - 11s/epoch - 516ms/step
# Epoch 126/1200
# 22/22 - 11s - loss: 0.6732 - accuracy: 0.4456 - 11s/epoch - 511ms/step
# Epoch 127/1200
# 22/22 - 11s - loss: 0.6681 - accuracy: 0.4488 - 11s/epoch - 512ms/step
# Epoch 128/1200
# 22/22 - 11s - loss: 0.6674 - accuracy: 0.4552 - 11s/epoch - 514ms/step
# Epoch 129/1200
# 22/22 - 10s - loss: 0.6615 - accuracy: 0.4506 - 10s/epoch - 459ms/step
# Epoch 130/1200
# 22/22 - 11s - loss: 0.6557 - accuracy: 0.4437 - 11s/epoch - 511ms/step
# Epoch 131/1200
# 22/22 - 11s - loss: 0.6522 - accuracy: 0.4424 - 11s/epoch - 509ms/step
# Epoch 132/1200
# 22/22 - 11s - loss: 0.6444 - accuracy: 0.4547 - 11s/epoch - 518ms/step
# Epoch 133/1200
# 22/22 - 11s - loss: 0.6507 - accuracy: 0.4597 - 11s/epoch - 513ms/step
# Epoch 134/1200
# 22/22 - 11s - loss: 0.6334 - accuracy: 0.4629 - 11s/epoch - 512ms/step
# Epoch 135/1200
# 22/22 - 11s - loss: 0.6285 - accuracy: 0.4597 - 11s/epoch - 511ms/step
# Epoch 136/1200
# 22/22 - 11s - loss: 0.6302 - accuracy: 0.4721 - 11s/epoch - 510ms/step
# Epoch 137/1200
# 22/22 - 10s - loss: 0.6139 - accuracy: 0.4611 - 10s/epoch - 461ms/step
# Epoch 138/1200
# 22/22 - 11s - loss: 0.6157 - accuracy: 0.4730 - 11s/epoch - 514ms/step
# Epoch 139/1200
# 22/22 - 11s - loss: 0.6071 - accuracy: 0.4597 - 11s/epoch - 513ms/step
# Epoch 140/1200
# 22/22 - 11s - loss: 0.6007 - accuracy: 0.4748 - 11s/epoch - 515ms/step
# Epoch 141/1200
# 22/22 - 11s - loss: 0.5979 - accuracy: 0.4629 - 11s/epoch - 513ms/step
# Epoch 142/1200
# 22/22 - 11s - loss: 0.5860 - accuracy: 0.4808 - 11s/epoch - 511ms/step
# Epoch 143/1200
# 22/22 - 11s - loss: 0.5811 - accuracy: 0.4831 - 11s/epoch - 512ms/step
# Epoch 144/1200
# 22/22 - 11s - loss: 0.5775 - accuracy: 0.4817 - 11s/epoch - 502ms/step
# Epoch 145/1200
# 22/22 - 10s - loss: 0.5656 - accuracy: 0.4771 - 10s/epoch - 467ms/step
# Epoch 146/1200
# 22/22 - 11s - loss: 0.5648 - accuracy: 0.4808 - 11s/epoch - 512ms/step
# Epoch 147/1200
# 22/22 - 11s - loss: 0.5500 - accuracy: 0.4881 - 11s/epoch - 511ms/step
# Epoch 148/1200
# 22/22 - 11s - loss: 0.5453 - accuracy: 0.4913 - 11s/epoch - 512ms/step
# Epoch 149/1200
# 22/22 - 11s - loss: 0.5417 - accuracy: 0.4982 - 11s/epoch - 510ms/step
# Epoch 150/1200
# 22/22 - 11s - loss: 0.5355 - accuracy: 0.4854 - 11s/epoch - 510ms/step
# Epoch 151/1200
# 22/22 - 11s - loss: 0.5297 - accuracy: 0.4991 - 11s/epoch - 515ms/step
# Epoch 152/1200
# 22/22 - 11s - loss: 0.5316 - accuracy: 0.5064 - 11s/epoch - 493ms/step
# Epoch 153/1200
# 22/22 - 11s - loss: 0.5163 - accuracy: 0.5000 - 11s/epoch - 478ms/step
# Epoch 154/1200
# 22/22 - 11s - loss: 0.5075 - accuracy: 0.5114 - 11s/epoch - 514ms/step
# Epoch 155/1200
# 22/22 - 11s - loss: 0.5005 - accuracy: 0.5151 - 11s/epoch - 514ms/step
# Epoch 156/1200
# 22/22 - 11s - loss: 0.4998 - accuracy: 0.5046 - 11s/epoch - 516ms/step
# Epoch 157/1200
# 22/22 - 11s - loss: 0.4905 - accuracy: 0.5087 - 11s/epoch - 513ms/step
# Epoch 158/1200
# 22/22 - 11s - loss: 0.4876 - accuracy: 0.5156 - 11s/epoch - 513ms/step
# Epoch 159/1200
# 22/22 - 11s - loss: 0.4825 - accuracy: 0.5210 - 11s/epoch - 514ms/step
# Epoch 160/1200
# 22/22 - 11s - loss: 0.4765 - accuracy: 0.5215 - 11s/epoch - 487ms/step
# Epoch 161/1200
# 22/22 - 11s - loss: 0.4651 - accuracy: 0.5274 - 11s/epoch - 479ms/step
# Epoch 162/1200
# 22/22 - 11s - loss: 0.4623 - accuracy: 0.5252 - 11s/epoch - 514ms/step
# Epoch 163/1200
# 22/22 - 11s - loss: 0.4547 - accuracy: 0.5416 - 11s/epoch - 509ms/step
# Epoch 164/1200
# 22/22 - 11s - loss: 0.4491 - accuracy: 0.5357 - 11s/epoch - 511ms/step
# Epoch 165/1200
# 22/22 - 11s - loss: 0.4433 - accuracy: 0.5371 - 11s/epoch - 517ms/step
# Epoch 166/1200
# 22/22 - 11s - loss: 0.4359 - accuracy: 0.5439 - 11s/epoch - 512ms/step
# Epoch 167/1200
# 22/22 - 11s - loss: 0.4256 - accuracy: 0.5540 - 11s/epoch - 513ms/step
# Epoch 168/1200
# 22/22 - 11s - loss: 0.4265 - accuracy: 0.5371 - 11s/epoch - 482ms/step
# Epoch 169/1200
# 22/22 - 11s - loss: 0.4216 - accuracy: 0.5439 - 11s/epoch - 493ms/step
# Epoch 170/1200
# 22/22 - 11s - loss: 0.4131 - accuracy: 0.5590 - 11s/epoch - 517ms/step
# Epoch 171/1200
# 22/22 - 11s - loss: 0.4158 - accuracy: 0.5535 - 11s/epoch - 510ms/step
# Epoch 172/1200
# 22/22 - 11s - loss: 0.4012 - accuracy: 0.5704 - 11s/epoch - 514ms/step
# Epoch 173/1200
# 22/22 - 11s - loss: 0.3978 - accuracy: 0.5654 - 11s/epoch - 516ms/step
# Epoch 174/1200
# 22/22 - 11s - loss: 0.3977 - accuracy: 0.5645 - 11s/epoch - 514ms/step
# Epoch 175/1200
# 22/22 - 11s - loss: 0.3906 - accuracy: 0.5759 - 11s/epoch - 517ms/step
# Epoch 176/1200
# 22/22 - 11s - loss: 0.3839 - accuracy: 0.5718 - 11s/epoch - 493ms/step
# Epoch 177/1200
# 22/22 - 11s - loss: 0.3840 - accuracy: 0.5805 - 11s/epoch - 480ms/step
# Epoch 178/1200
# 22/22 - 11s - loss: 0.3827 - accuracy: 0.5846 - 11s/epoch - 514ms/step
# Epoch 179/1200
# 22/22 - 11s - loss: 0.3750 - accuracy: 0.5823 - 11s/epoch - 510ms/step
# Epoch 180/1200
# 22/22 - 11s - loss: 0.3713 - accuracy: 0.5897 - 11s/epoch - 514ms/step
# Epoch 181/1200
# 22/22 - 11s - loss: 0.3623 - accuracy: 0.6038 - 11s/epoch - 514ms/step
# Epoch 182/1200
# 22/22 - 11s - loss: 0.3611 - accuracy: 0.5997 - 11s/epoch - 511ms/step
# Epoch 183/1200
# 22/22 - 11s - loss: 0.3538 - accuracy: 0.5901 - 11s/epoch - 511ms/step
# Epoch 184/1200
# 22/22 - 10s - loss: 0.3532 - accuracy: 0.6093 - 10s/epoch - 473ms/step
# Epoch 185/1200
# 22/22 - 11s - loss: 0.3496 - accuracy: 0.6006 - 11s/epoch - 491ms/step
# Epoch 186/1200
# 22/22 - 11s - loss: 0.3467 - accuracy: 0.6052 - 11s/epoch - 512ms/step
# Epoch 187/1200
# 22/22 - 11s - loss: 0.3362 - accuracy: 0.6153 - 11s/epoch - 511ms/step
# Epoch 188/1200
# 22/22 - 11s - loss: 0.3407 - accuracy: 0.6093 - 11s/epoch - 515ms/step
# Epoch 189/1200
# 22/22 - 11s - loss: 0.3336 - accuracy: 0.6020 - 11s/epoch - 511ms/step
# Epoch 190/1200
# 22/22 - 11s - loss: 0.3277 - accuracy: 0.6194 - 11s/epoch - 510ms/step
# Epoch 191/1200
# 22/22 - 11s - loss: 0.3199 - accuracy: 0.6267 - 11s/epoch - 511ms/step
# Epoch 192/1200
# 22/22 - 10s - loss: 0.3218 - accuracy: 0.6212 - 10s/epoch - 467ms/step
# Epoch 193/1200
# 22/22 - 11s - loss: 0.3176 - accuracy: 0.6285 - 11s/epoch - 505ms/step
# Epoch 194/1200
# 22/22 - 11s - loss: 0.3095 - accuracy: 0.6199 - 11s/epoch - 512ms/step
# Epoch 195/1200
# 22/22 - 11s - loss: 0.3073 - accuracy: 0.6240 - 11s/epoch - 511ms/step
# Epoch 196/1200
# 22/22 - 11s - loss: 0.3064 - accuracy: 0.6386 - 11s/epoch - 511ms/step
# Epoch 197/1200
# 22/22 - 11s - loss: 0.2977 - accuracy: 0.6272 - 11s/epoch - 515ms/step
# Epoch 198/1200
# 22/22 - 11s - loss: 0.2992 - accuracy: 0.6276 - 11s/epoch - 514ms/step
# Epoch 199/1200
# 22/22 - 11s - loss: 0.2988 - accuracy: 0.6423 - 11s/epoch - 511ms/step
# Epoch 200/1200
# 22/22 - 10s - loss: 0.2907 - accuracy: 0.6473 - 10s/epoch - 462ms/step
# Epoch 201/1200
# 22/22 - 11s - loss: 0.2898 - accuracy: 0.6468 - 11s/epoch - 509ms/step
# Epoch 202/1200
# 22/22 - 11s - loss: 0.2839 - accuracy: 0.6427 - 11s/epoch - 516ms/step
# Epoch 203/1200
# 22/22 - 11s - loss: 0.2796 - accuracy: 0.6532 - 11s/epoch - 514ms/step
# Epoch 204/1200
# 22/22 - 11s - loss: 0.2771 - accuracy: 0.6418 - 11s/epoch - 513ms/step
# Epoch 205/1200
# 22/22 - 11s - loss: 0.2737 - accuracy: 0.6441 - 11s/epoch - 516ms/step
# Epoch 206/1200
# 22/22 - 11s - loss: 0.2712 - accuracy: 0.6601 - 11s/epoch - 518ms/step
# Epoch 207/1200
# 22/22 - 11s - loss: 0.2643 - accuracy: 0.6505 - 11s/epoch - 515ms/step
# Epoch 208/1200
# 22/22 - 11s - loss: 0.2649 - accuracy: 0.6523 - 11s/epoch - 479ms/step
# Epoch 209/1200
# 22/22 - 11s - loss: 0.2591 - accuracy: 0.6747 - 11s/epoch - 495ms/step
# Epoch 210/1200
# 22/22 - 11s - loss: 0.2571 - accuracy: 0.6597 - 11s/epoch - 514ms/step
# Epoch 211/1200
# 22/22 - 11s - loss: 0.2483 - accuracy: 0.6757 - 11s/epoch - 513ms/step
# Epoch 212/1200
# 22/22 - 11s - loss: 0.2497 - accuracy: 0.6757 - 11s/epoch - 512ms/step
# Epoch 213/1200
# 22/22 - 11s - loss: 0.2414 - accuracy: 0.6702 - 11s/epoch - 514ms/step
# Epoch 214/1200
# 22/22 - 11s - loss: 0.2385 - accuracy: 0.6738 - 11s/epoch - 508ms/step
# Epoch 215/1200
# 22/22 - 11s - loss: 0.2403 - accuracy: 0.6839 - 11s/epoch - 514ms/step
# Epoch 216/1200
# 22/22 - 10s - loss: 0.2369 - accuracy: 0.6807 - 10s/epoch - 471ms/step
# Epoch 217/1200
# 22/22 - 11s - loss: 0.2344 - accuracy: 0.6770 - 11s/epoch - 499ms/step
# Epoch 218/1200
# 22/22 - 11s - loss: 0.2280 - accuracy: 0.6697 - 11s/epoch - 514ms/step
# Epoch 219/1200
# 22/22 - 11s - loss: 0.2216 - accuracy: 0.6976 - 11s/epoch - 515ms/step
# Epoch 220/1200
# 22/22 - 11s - loss: 0.2224 - accuracy: 0.6766 - 11s/epoch - 514ms/step
# Epoch 221/1200
# 22/22 - 11s - loss: 0.2188 - accuracy: 0.6866 - 11s/epoch - 515ms/step
# Epoch 222/1200
# 22/22 - 11s - loss: 0.2158 - accuracy: 0.6908 - 11s/epoch - 516ms/step
# Epoch 223/1200
# 22/22 - 11s - loss: 0.2108 - accuracy: 0.7036 - 11s/epoch - 509ms/step
# Epoch 224/1200
# 22/22 - 11s - loss: 0.2072 - accuracy: 0.7077 - 11s/epoch - 484ms/step
# Epoch 225/1200
# 22/22 - 11s - loss: 0.2033 - accuracy: 0.7081 - 11s/epoch - 497ms/step
# Epoch 226/1200
# 22/22 - 11s - loss: 0.2040 - accuracy: 0.7054 - 11s/epoch - 511ms/step
# Epoch 227/1200
# 22/22 - 11s - loss: 0.1965 - accuracy: 0.7072 - 11s/epoch - 516ms/step
# Epoch 228/1200
# 22/22 - 11s - loss: 0.1954 - accuracy: 0.7145 - 11s/epoch - 512ms/step
# Epoch 229/1200
# 22/22 - 11s - loss: 0.1930 - accuracy: 0.7132 - 11s/epoch - 515ms/step
# Epoch 230/1200
# 22/22 - 11s - loss: 0.1882 - accuracy: 0.7145 - 11s/epoch - 514ms/step
# Epoch 231/1200
# 22/22 - 11s - loss: 0.1865 - accuracy: 0.7210 - 11s/epoch - 514ms/step
# Epoch 232/1200
# 22/22 - 11s - loss: 0.1845 - accuracy: 0.7118 - 11s/epoch - 478ms/step
# Epoch 233/1200
# 22/22 - 11s - loss: 0.1771 - accuracy: 0.7296 - 11s/epoch - 492ms/step
# Epoch 234/1200
# 22/22 - 11s - loss: 0.1778 - accuracy: 0.7159 - 11s/epoch - 512ms/step
# Epoch 235/1200
# 22/22 - 11s - loss: 0.1732 - accuracy: 0.7168 - 11s/epoch - 514ms/step
# Epoch 236/1200
# 22/22 - 11s - loss: 0.1723 - accuracy: 0.7292 - 11s/epoch - 513ms/step
# Epoch 237/1200
# 22/22 - 11s - loss: 0.1693 - accuracy: 0.7383 - 11s/epoch - 508ms/step
# Epoch 238/1200
# 22/22 - 11s - loss: 0.1641 - accuracy: 0.7306 - 11s/epoch - 512ms/step
# Epoch 239/1200
# 22/22 - 11s - loss: 0.1647 - accuracy: 0.7338 - 11s/epoch - 510ms/step
# Epoch 240/1200
# 22/22 - 11s - loss: 0.1622 - accuracy: 0.7434 - 11s/epoch - 479ms/step
# Epoch 241/1200
# 22/22 - 11s - loss: 0.1569 - accuracy: 0.7255 - 11s/epoch - 490ms/step
# Epoch 242/1200
# 22/22 - 11s - loss: 0.1541 - accuracy: 0.7406 - 11s/epoch - 512ms/step
# Epoch 243/1200
# 22/22 - 11s - loss: 0.1554 - accuracy: 0.7498 - 11s/epoch - 511ms/step
# Epoch 244/1200
# 22/22 - 11s - loss: 0.1499 - accuracy: 0.7443 - 11s/epoch - 511ms/step
# Epoch 245/1200
# 22/22 - 11s - loss: 0.1498 - accuracy: 0.7489 - 11s/epoch - 515ms/step
# Epoch 246/1200
# 22/22 - 11s - loss: 0.1468 - accuracy: 0.7443 - 11s/epoch - 514ms/step
# Epoch 247/1200
# 22/22 - 11s - loss: 0.1437 - accuracy: 0.7438 - 11s/epoch - 514ms/step
# Epoch 248/1200
# 22/22 - 10s - loss: 0.1387 - accuracy: 0.7498 - 10s/epoch - 473ms/step
# Epoch 249/1200
# 22/22 - 11s - loss: 0.1341 - accuracy: 0.7452 - 11s/epoch - 498ms/step
# Epoch 250/1200
# 22/22 - 11s - loss: 0.1349 - accuracy: 0.7566 - 11s/epoch - 515ms/step
# Epoch 251/1200
# 22/22 - 11s - loss: 0.1333 - accuracy: 0.7539 - 11s/epoch - 514ms/step
# Epoch 252/1200
# 22/22 - 11s - loss: 0.1300 - accuracy: 0.7539 - 11s/epoch - 514ms/step
# Epoch 253/1200
# 22/22 - 11s - loss: 0.1289 - accuracy: 0.7575 - 11s/epoch - 517ms/step
# Epoch 254/1200
# 22/22 - 11s - loss: 0.1259 - accuracy: 0.7708 - 11s/epoch - 517ms/step
# Epoch 255/1200
# 22/22 - 11s - loss: 0.1252 - accuracy: 0.7493 - 11s/epoch - 514ms/step
# Epoch 256/1200
# 22/22 - 11s - loss: 0.1220 - accuracy: 0.7649 - 11s/epoch - 480ms/step
# Epoch 257/1200
# 22/22 - 11s - loss: 0.1250 - accuracy: 0.7736 - 11s/epoch - 492ms/step
# Epoch 258/1200
# 22/22 - 11s - loss: 0.1188 - accuracy: 0.7726 - 11s/epoch - 512ms/step
# Epoch 259/1200
# 22/22 - 11s - loss: 0.1192 - accuracy: 0.7548 - 11s/epoch - 513ms/step
# Epoch 260/1200
# 22/22 - 11s - loss: 0.1150 - accuracy: 0.7777 - 11s/epoch - 516ms/step
# Epoch 261/1200
# 22/22 - 11s - loss: 0.1154 - accuracy: 0.7722 - 11s/epoch - 515ms/step
# Epoch 262/1200
# 22/22 - 11s - loss: 0.1123 - accuracy: 0.7672 - 11s/epoch - 514ms/step
# Epoch 263/1200
# 22/22 - 11s - loss: 0.1078 - accuracy: 0.7923 - 11s/epoch - 521ms/step
# Epoch 264/1200
# 22/22 - 11s - loss: 0.1086 - accuracy: 0.7891 - 11s/epoch - 488ms/step
# Epoch 265/1200
# 22/22 - 11s - loss: 0.1050 - accuracy: 0.7777 - 11s/epoch - 487ms/step
# Epoch 266/1200
# 22/22 - 11s - loss: 0.1058 - accuracy: 0.7827 - 11s/epoch - 514ms/step
# Epoch 267/1200
# 22/22 - 11s - loss: 0.1026 - accuracy: 0.7827 - 11s/epoch - 512ms/step
# Epoch 268/1200
# 22/22 - 11s - loss: 0.1035 - accuracy: 0.7768 - 11s/epoch - 512ms/step
# Epoch 269/1200
# 22/22 - 11s - loss: 0.0994 - accuracy: 0.7859 - 11s/epoch - 512ms/step
# Epoch 270/1200
# 22/22 - 11s - loss: 0.1008 - accuracy: 0.7827 - 11s/epoch - 514ms/step
# Epoch 271/1200
# 22/22 - 11s - loss: 0.0962 - accuracy: 0.7887 - 11s/epoch - 514ms/step
# Epoch 272/1200
# 22/22 - 11s - loss: 0.0947 - accuracy: 0.8005 - 11s/epoch - 494ms/step
# Epoch 273/1200
# 22/22 - 11s - loss: 0.0959 - accuracy: 0.7960 - 11s/epoch - 479ms/step
# Epoch 274/1200
# 22/22 - 11s - loss: 0.0923 - accuracy: 0.8005 - 11s/epoch - 510ms/step
# Epoch 275/1200
# 22/22 - 11s - loss: 0.0922 - accuracy: 0.7887 - 11s/epoch - 514ms/step
# Epoch 276/1200
# 22/22 - 11s - loss: 0.0896 - accuracy: 0.7964 - 11s/epoch - 511ms/step
# Epoch 277/1200
# 22/22 - 11s - loss: 0.0876 - accuracy: 0.7818 - 11s/epoch - 514ms/step
# Epoch 278/1200
# 22/22 - 11s - loss: 0.0879 - accuracy: 0.7969 - 11s/epoch - 512ms/step
# Epoch 279/1200
# 22/22 - 11s - loss: 0.0862 - accuracy: 0.8115 - 11s/epoch - 515ms/step
# Epoch 280/1200
# 22/22 - 11s - loss: 0.0852 - accuracy: 0.8019 - 11s/epoch - 500ms/step
# Epoch 281/1200
# 22/22 - 10s - loss: 0.0821 - accuracy: 0.7905 - 10s/epoch - 475ms/step
# Epoch 282/1200
# 22/22 - 11s - loss: 0.0837 - accuracy: 0.8042 - 11s/epoch - 510ms/step
# Epoch 283/1200
# 22/22 - 11s - loss: 0.0826 - accuracy: 0.7983 - 11s/epoch - 513ms/step
# Epoch 284/1200
# 22/22 - 11s - loss: 0.0809 - accuracy: 0.8083 - 11s/epoch - 511ms/step
# Epoch 285/1200
# 22/22 - 11s - loss: 0.0791 - accuracy: 0.8129 - 11s/epoch - 511ms/step
# Epoch 286/1200
# 22/22 - 11s - loss: 0.0786 - accuracy: 0.8138 - 11s/epoch - 513ms/step
# Epoch 287/1200
# 22/22 - 11s - loss: 0.0775 - accuracy: 0.8143 - 11s/epoch - 510ms/step
# Epoch 288/1200
# 22/22 - 11s - loss: 0.0744 - accuracy: 0.8115 - 11s/epoch - 505ms/step
# Epoch 289/1200
# 22/22 - 10s - loss: 0.0754 - accuracy: 0.8129 - 10s/epoch - 474ms/step
# Epoch 290/1200
# 22/22 - 11s - loss: 0.0750 - accuracy: 0.8083 - 11s/epoch - 522ms/step
# Epoch 291/1200
# 22/22 - 11s - loss: 0.0756 - accuracy: 0.8166 - 11s/epoch - 505ms/step
# Epoch 292/1200
# 22/22 - 11s - loss: 0.0709 - accuracy: 0.8115 - 11s/epoch - 505ms/step
# Epoch 293/1200
# 22/22 - 11s - loss: 0.0704 - accuracy: 0.8166 - 11s/epoch - 495ms/step
# Epoch 294/1200
# 22/22 - 11s - loss: 0.0707 - accuracy: 0.8111 - 11s/epoch - 498ms/step
# Epoch 295/1200
# 22/22 - 11s - loss: 0.0688 - accuracy: 0.8207 - 11s/epoch - 502ms/step
# Epoch 296/1200
# 22/22 - 11s - loss: 0.0695 - accuracy: 0.8230 - 11s/epoch - 512ms/step
# Epoch 297/1200
# 22/22 - 11s - loss: 0.0667 - accuracy: 0.8102 - 11s/epoch - 512ms/step
# Epoch 298/1200
# 22/22 - 11s - loss: 0.0636 - accuracy: 0.8220 - 11s/epoch - 515ms/step
# Epoch 299/1200
# 22/22 - 11s - loss: 0.0666 - accuracy: 0.8175 - 11s/epoch - 516ms/step
# Epoch 300/1200
# 22/22 - 11s - loss: 0.0644 - accuracy: 0.8317 - 11s/epoch - 506ms/step
# Epoch 301/1200
# 22/22 - 11s - loss: 0.0650 - accuracy: 0.8330 - 11s/epoch - 499ms/step
# Epoch 302/1200
# 22/22 - 11s - loss: 0.0635 - accuracy: 0.8248 - 11s/epoch - 502ms/step
# Epoch 303/1200
# 22/22 - 11s - loss: 0.0628 - accuracy: 0.8303 - 11s/epoch - 494ms/step
# Epoch 304/1200
# 22/22 - 10s - loss: 0.0639 - accuracy: 0.8161 - 10s/epoch - 477ms/step
# Epoch 305/1200
# 22/22 - 11s - loss: 0.0623 - accuracy: 0.8248 - 11s/epoch - 500ms/step
# Epoch 306/1200
# 22/22 - 11s - loss: 0.0605 - accuracy: 0.8312 - 11s/epoch - 500ms/step
# Epoch 307/1200
# 22/22 - 11s - loss: 0.0614 - accuracy: 0.8298 - 11s/epoch - 501ms/step
# Epoch 308/1200
# 22/22 - 11s - loss: 0.0609 - accuracy: 0.8403 - 11s/epoch - 502ms/step
# Epoch 309/1200
# 22/22 - 11s - loss: 0.0607 - accuracy: 0.8367 - 11s/epoch - 498ms/step
# Epoch 310/1200
# 22/22 - 11s - loss: 0.0586 - accuracy: 0.8271 - 11s/epoch - 499ms/step
# Epoch 311/1200
# 22/22 - 11s - loss: 0.0594 - accuracy: 0.8358 - 11s/epoch - 500ms/step
# Epoch 312/1200
# 22/22 - 11s - loss: 0.0573 - accuracy: 0.8417 - 11s/epoch - 498ms/step
# Epoch 313/1200
# 22/22 - 11s - loss: 0.0582 - accuracy: 0.8257 - 11s/epoch - 498ms/step
# Epoch 314/1200
# 22/22 - 11s - loss: 0.0548 - accuracy: 0.8472 - 11s/epoch - 495ms/step
# Epoch 315/1200
# 22/22 - 11s - loss: 0.0560 - accuracy: 0.8417 - 11s/epoch - 498ms/step
# Epoch 316/1200
# 22/22 - 11s - loss: 0.0559 - accuracy: 0.8335 - 11s/epoch - 500ms/step
# Epoch 317/1200
# 22/22 - 10s - loss: 0.0552 - accuracy: 0.8422 - 10s/epoch - 473ms/step
# Epoch 318/1200
# 22/22 - 11s - loss: 0.0550 - accuracy: 0.8294 - 11s/epoch - 492ms/step
# Epoch 319/1200
# 22/22 - 11s - loss: 0.0543 - accuracy: 0.8527 - 11s/epoch - 497ms/step
# Epoch 320/1200
# 22/22 - 11s - loss: 0.0549 - accuracy: 0.8317 - 11s/epoch - 496ms/step
# Epoch 321/1200
# 22/22 - 11s - loss: 0.0532 - accuracy: 0.8390 - 11s/epoch - 496ms/step
# Epoch 322/1200
# 22/22 - 11s - loss: 0.0529 - accuracy: 0.8367 - 11s/epoch - 496ms/step
# Epoch 323/1200
# 22/22 - 11s - loss: 0.0517 - accuracy: 0.8490 - 11s/epoch - 498ms/step
# Epoch 324/1200
# 22/22 - 11s - loss: 0.0517 - accuracy: 0.8381 - 11s/epoch - 497ms/step
# Epoch 325/1200
# 22/22 - 11s - loss: 0.0519 - accuracy: 0.8481 - 11s/epoch - 496ms/step
# Epoch 326/1200
# 22/22 - 11s - loss: 0.0524 - accuracy: 0.8381 - 11s/epoch - 502ms/step
# Epoch 327/1200
# 22/22 - 11s - loss: 0.0512 - accuracy: 0.8385 - 11s/epoch - 499ms/step
# Epoch 328/1200
# 22/22 - 11s - loss: 0.0504 - accuracy: 0.8545 - 11s/epoch - 501ms/step
# Epoch 329/1200
# 22/22 - 11s - loss: 0.0498 - accuracy: 0.8458 - 11s/epoch - 501ms/step
# Epoch 330/1200
# 22/22 - 11s - loss: 0.0493 - accuracy: 0.8541 - 11s/epoch - 486ms/step
# Epoch 331/1200
# 22/22 - 11s - loss: 0.0484 - accuracy: 0.8486 - 11s/epoch - 477ms/step
# Epoch 332/1200
# 22/22 - 11s - loss: 0.0480 - accuracy: 0.8463 - 11s/epoch - 500ms/step
# Epoch 333/1200
# 22/22 - 11s - loss: 0.0465 - accuracy: 0.8518 - 11s/epoch - 501ms/step
# Epoch 334/1200
# 22/22 - 11s - loss: 0.0468 - accuracy: 0.8490 - 11s/epoch - 503ms/step
# Epoch 335/1200
# 22/22 - 11s - loss: 0.0486 - accuracy: 0.8527 - 11s/epoch - 499ms/step
# Epoch 336/1200
# 22/22 - 11s - loss: 0.0476 - accuracy: 0.8513 - 11s/epoch - 503ms/step
# Epoch 337/1200
# 22/22 - 11s - loss: 0.0475 - accuracy: 0.8481 - 11s/epoch - 496ms/step
# Epoch 338/1200
# 22/22 - 11s - loss: 0.0468 - accuracy: 0.8500 - 11s/epoch - 498ms/step
# Epoch 339/1200
# 22/22 - 11s - loss: 0.0458 - accuracy: 0.8554 - 11s/epoch - 497ms/step
# Epoch 340/1200
# 22/22 - 11s - loss: 0.0456 - accuracy: 0.8568 - 11s/epoch - 496ms/step
# Epoch 341/1200
# 22/22 - 11s - loss: 0.0439 - accuracy: 0.8618 - 11s/epoch - 495ms/step
# Epoch 342/1200
# 22/22 - 11s - loss: 0.0454 - accuracy: 0.8527 - 11s/epoch - 498ms/step
# Epoch 343/1200
# 22/22 - 11s - loss: 0.0443 - accuracy: 0.8513 - 11s/epoch - 488ms/step
# Epoch 344/1200
# 22/22 - 10s - loss: 0.0441 - accuracy: 0.8618 - 10s/epoch - 469ms/step
# Epoch 345/1200
# 22/22 - 11s - loss: 0.0451 - accuracy: 0.8541 - 11s/epoch - 498ms/step
# Epoch 346/1200
# 22/22 - 11s - loss: 0.0429 - accuracy: 0.8541 - 11s/epoch - 496ms/step
# Epoch 347/1200
# 22/22 - 11s - loss: 0.0422 - accuracy: 0.8509 - 11s/epoch - 498ms/step
# Epoch 348/1200
# 22/22 - 11s - loss: 0.0433 - accuracy: 0.8591 - 11s/epoch - 498ms/step
# Epoch 349/1200
# 22/22 - 11s - loss: 0.0434 - accuracy: 0.8591 - 11s/epoch - 501ms/step
# Epoch 350/1200
# 22/22 - 11s - loss: 0.0429 - accuracy: 0.8541 - 11s/epoch - 496ms/step
# Epoch 351/1200
# 22/22 - 11s - loss: 0.0430 - accuracy: 0.8618 - 11s/epoch - 499ms/step
# Epoch 352/1200
# 22/22 - 11s - loss: 0.0424 - accuracy: 0.8756 - 11s/epoch - 498ms/step
# Epoch 353/1200
# 22/22 - 11s - loss: 0.0413 - accuracy: 0.8564 - 11s/epoch - 497ms/step
# Epoch 354/1200
# 22/22 - 11s - loss: 0.0411 - accuracy: 0.8609 - 11s/epoch - 496ms/step
# Epoch 355/1200
# 22/22 - 11s - loss: 0.0412 - accuracy: 0.8669 - 11s/epoch - 499ms/step
# Epoch 356/1200
# 22/22 - 11s - loss: 0.0411 - accuracy: 0.8637 - 11s/epoch - 485ms/step
# Epoch 357/1200
# 22/22 - 11s - loss: 0.0406 - accuracy: 0.8573 - 11s/epoch - 479ms/step
# Epoch 358/1200
# 22/22 - 11s - loss: 0.0412 - accuracy: 0.8628 - 11s/epoch - 495ms/step
# Epoch 359/1200
# 22/22 - 11s - loss: 0.0391 - accuracy: 0.8710 - 11s/epoch - 498ms/step
# Epoch 360/1200
# 22/22 - 11s - loss: 0.0391 - accuracy: 0.8660 - 11s/epoch - 501ms/step
# Epoch 361/1200
# 22/22 - 11s - loss: 0.0394 - accuracy: 0.8591 - 11s/epoch - 497ms/step
# Epoch 362/1200
# 22/22 - 11s - loss: 0.0382 - accuracy: 0.8522 - 11s/epoch - 495ms/step
# Epoch 363/1200
# 22/22 - 11s - loss: 0.0386 - accuracy: 0.8692 - 11s/epoch - 499ms/step
# Epoch 364/1200
# 22/22 - 11s - loss: 0.0388 - accuracy: 0.8641 - 11s/epoch - 497ms/step
# Epoch 365/1200
# 22/22 - 11s - loss: 0.0388 - accuracy: 0.8701 - 11s/epoch - 497ms/step
# Epoch 366/1200
# 22/22 - 11s - loss: 0.0379 - accuracy: 0.8692 - 11s/epoch - 498ms/step
# Epoch 367/1200
# 22/22 - 11s - loss: 0.0376 - accuracy: 0.8733 - 11s/epoch - 499ms/step
# Epoch 368/1200
# 22/22 - 11s - loss: 0.0373 - accuracy: 0.8591 - 11s/epoch - 502ms/step
# Epoch 369/1200
# 22/22 - 11s - loss: 0.0379 - accuracy: 0.8742 - 11s/epoch - 488ms/step
# Epoch 370/1200
# 22/22 - 10s - loss: 0.0368 - accuracy: 0.8651 - 10s/epoch - 474ms/step
# Epoch 371/1200
# 22/22 - 11s - loss: 0.0366 - accuracy: 0.8724 - 11s/epoch - 500ms/step
# Epoch 372/1200
# 22/22 - 11s - loss: 0.0357 - accuracy: 0.8692 - 11s/epoch - 496ms/step
# Epoch 373/1200
# 22/22 - 11s - loss: 0.0364 - accuracy: 0.8769 - 11s/epoch - 500ms/step
# Epoch 374/1200
# 22/22 - 11s - loss: 0.0367 - accuracy: 0.8696 - 11s/epoch - 500ms/step
# Epoch 375/1200
# 22/22 - 11s - loss: 0.0359 - accuracy: 0.8833 - 11s/epoch - 496ms/step
# Epoch 376/1200
# 22/22 - 11s - loss: 0.0364 - accuracy: 0.8774 - 11s/epoch - 497ms/step
# Epoch 377/1200
# 22/22 - 11s - loss: 0.0362 - accuracy: 0.8742 - 11s/epoch - 504ms/step
# Epoch 378/1200
# 22/22 - 11s - loss: 0.0353 - accuracy: 0.8705 - 11s/epoch - 500ms/step
# Epoch 379/1200
# 22/22 - 11s - loss: 0.0355 - accuracy: 0.8591 - 11s/epoch - 496ms/step
# Epoch 380/1200
# 22/22 - 11s - loss: 0.0365 - accuracy: 0.8728 - 11s/epoch - 501ms/step
# Epoch 381/1200
# 22/22 - 11s - loss: 0.0348 - accuracy: 0.8683 - 11s/epoch - 500ms/step
# Epoch 382/1200
# 22/22 - 11s - loss: 0.0347 - accuracy: 0.8705 - 11s/epoch - 497ms/step
# Epoch 383/1200
# 22/22 - 10s - loss: 0.0340 - accuracy: 0.8751 - 10s/epoch - 468ms/step
# Epoch 384/1200
# 22/22 - 11s - loss: 0.0345 - accuracy: 0.8779 - 11s/epoch - 491ms/step
# Epoch 385/1200
# 22/22 - 11s - loss: 0.0342 - accuracy: 0.8760 - 11s/epoch - 504ms/step
# Epoch 386/1200
# 22/22 - 11s - loss: 0.0344 - accuracy: 0.8705 - 11s/epoch - 497ms/step
# Epoch 387/1200
# 22/22 - 11s - loss: 0.0332 - accuracy: 0.8760 - 11s/epoch - 501ms/step
# Epoch 388/1200
# 22/22 - 11s - loss: 0.0336 - accuracy: 0.8701 - 11s/epoch - 497ms/step
# Epoch 389/1200
# 22/22 - 11s - loss: 0.0333 - accuracy: 0.8824 - 11s/epoch - 499ms/step
# Epoch 390/1200
# 22/22 - 11s - loss: 0.0333 - accuracy: 0.8628 - 11s/epoch - 497ms/step
# Epoch 391/1200
# 22/22 - 11s - loss: 0.0328 - accuracy: 0.8769 - 11s/epoch - 497ms/step
# Epoch 392/1200
# 22/22 - 11s - loss: 0.0328 - accuracy: 0.8783 - 11s/epoch - 497ms/step
# Epoch 393/1200
# 22/22 - 11s - loss: 0.0304 - accuracy: 0.8911 - 11s/epoch - 497ms/step
# Epoch 394/1200
# 22/22 - 11s - loss: 0.0318 - accuracy: 0.8760 - 11s/epoch - 493ms/step
# Epoch 395/1200
# 22/22 - 11s - loss: 0.0329 - accuracy: 0.8792 - 11s/epoch - 490ms/step
# Epoch 396/1200
# 22/22 - 10s - loss: 0.0319 - accuracy: 0.8760 - 10s/epoch - 462ms/step
# Epoch 397/1200
# 22/22 - 11s - loss: 0.0321 - accuracy: 0.8747 - 11s/epoch - 490ms/step
# Epoch 398/1200
# 22/22 - 11s - loss: 0.0314 - accuracy: 0.8705 - 11s/epoch - 494ms/step
# Epoch 399/1200
# 22/22 - 11s - loss: 0.0312 - accuracy: 0.8788 - 11s/epoch - 494ms/step
# Epoch 400/1200
# 22/22 - 11s - loss: 0.0325 - accuracy: 0.8797 - 11s/epoch - 495ms/step
# Epoch 401/1200
# 22/22 - 11s - loss: 0.0327 - accuracy: 0.8801 - 11s/epoch - 491ms/step
# Epoch 402/1200
# 22/22 - 11s - loss: 0.0318 - accuracy: 0.8898 - 11s/epoch - 492ms/step
# Epoch 403/1200
# 22/22 - 11s - loss: 0.0305 - accuracy: 0.8820 - 11s/epoch - 495ms/step
# Epoch 404/1200
# 22/22 - 11s - loss: 0.0309 - accuracy: 0.8801 - 11s/epoch - 495ms/step
# Epoch 405/1200
# 22/22 - 11s - loss: 0.0305 - accuracy: 0.8852 - 11s/epoch - 495ms/step
# Epoch 406/1200
# 22/22 - 11s - loss: 0.0301 - accuracy: 0.8898 - 11s/epoch - 494ms/step
# Epoch 407/1200
# 22/22 - 11s - loss: 0.0313 - accuracy: 0.8733 - 11s/epoch - 480ms/step
# Epoch 408/1200
# 22/22 - 10s - loss: 0.0298 - accuracy: 0.8705 - 10s/epoch - 474ms/step
# Epoch 409/1200
# 22/22 - 11s - loss: 0.0298 - accuracy: 0.8829 - 11s/epoch - 496ms/step
# Epoch 410/1200
# 22/22 - 11s - loss: 0.0297 - accuracy: 0.8774 - 11s/epoch - 496ms/step
# Epoch 411/1200
# 22/22 - 11s - loss: 0.0295 - accuracy: 0.8902 - 11s/epoch - 495ms/step
# Epoch 412/1200
# 22/22 - 11s - loss: 0.0288 - accuracy: 0.8829 - 11s/epoch - 496ms/step
# Epoch 413/1200
# 22/22 - 11s - loss: 0.0288 - accuracy: 0.8907 - 11s/epoch - 498ms/step
# Epoch 414/1200
# 22/22 - 11s - loss: 0.0295 - accuracy: 0.8925 - 11s/epoch - 497ms/step
# Epoch 415/1200
# 22/22 - 11s - loss: 0.0288 - accuracy: 0.8893 - 11s/epoch - 500ms/step
# Epoch 416/1200
# 22/22 - 11s - loss: 0.0294 - accuracy: 0.8774 - 11s/epoch - 497ms/step
# Epoch 417/1200
# 22/22 - 11s - loss: 0.0289 - accuracy: 0.8888 - 11s/epoch - 499ms/step
# Epoch 418/1200
# 22/22 - 11s - loss: 0.0293 - accuracy: 0.8815 - 11s/epoch - 496ms/step
# Epoch 419/1200
# 22/22 - 11s - loss: 0.0289 - accuracy: 0.8902 - 11s/epoch - 497ms/step
# Epoch 420/1200
# 22/22 - 11s - loss: 0.0284 - accuracy: 0.8861 - 11s/epoch - 484ms/step
# Epoch 421/1200
# 22/22 - 10s - loss: 0.0277 - accuracy: 0.8948 - 10s/epoch - 473ms/step
# Epoch 422/1200
# 22/22 - 11s - loss: 0.0278 - accuracy: 0.8783 - 11s/epoch - 495ms/step
# Epoch 423/1200
# 22/22 - 11s - loss: 0.0279 - accuracy: 0.8861 - 11s/epoch - 497ms/step
# Epoch 424/1200
# 22/22 - 11s - loss: 0.0280 - accuracy: 0.8797 - 11s/epoch - 501ms/step
# Epoch 425/1200
# 22/22 - 11s - loss: 0.0281 - accuracy: 0.8847 - 11s/epoch - 494ms/step
# Epoch 426/1200
# 22/22 - 11s - loss: 0.0274 - accuracy: 0.8907 - 11s/epoch - 496ms/step
# Epoch 427/1200
# 22/22 - 11s - loss: 0.0273 - accuracy: 0.8975 - 11s/epoch - 494ms/step
# Epoch 428/1200
# 22/22 - 11s - loss: 0.0268 - accuracy: 0.8861 - 11s/epoch - 496ms/step
# Epoch 429/1200
# 22/22 - 11s - loss: 0.0274 - accuracy: 0.8861 - 11s/epoch - 497ms/step
# Epoch 430/1200
# 22/22 - 11s - loss: 0.0273 - accuracy: 0.8829 - 11s/epoch - 497ms/step
# Epoch 431/1200
# 22/22 - 11s - loss: 0.0272 - accuracy: 0.8856 - 11s/epoch - 497ms/step
# Epoch 432/1200
# 22/22 - 11s - loss: 0.0269 - accuracy: 0.8751 - 11s/epoch - 494ms/step
# Epoch 433/1200
# 22/22 - 10s - loss: 0.0267 - accuracy: 0.8934 - 10s/epoch - 461ms/step
# Epoch 434/1200
# 22/22 - 11s - loss: 0.0275 - accuracy: 0.8893 - 11s/epoch - 493ms/step
# Epoch 435/1200
# 22/22 - 11s - loss: 0.0272 - accuracy: 0.8907 - 11s/epoch - 495ms/step
# Epoch 436/1200
# 22/22 - 11s - loss: 0.0274 - accuracy: 0.8966 - 11s/epoch - 498ms/step
# Epoch 437/1200
# 22/22 - 11s - loss: 0.0268 - accuracy: 0.8888 - 11s/epoch - 495ms/step
# Epoch 438/1200
# 22/22 - 11s - loss: 0.0264 - accuracy: 0.8893 - 11s/epoch - 499ms/step
# Epoch 439/1200
# 22/22 - 11s - loss: 0.0265 - accuracy: 0.8861 - 11s/epoch - 495ms/step
# Epoch 440/1200
# 22/22 - 11s - loss: 0.0272 - accuracy: 0.8852 - 11s/epoch - 495ms/step
# Epoch 441/1200
# 22/22 - 11s - loss: 0.0266 - accuracy: 0.8925 - 11s/epoch - 495ms/step
# Epoch 442/1200
# 22/22 - 11s - loss: 0.0265 - accuracy: 0.8843 - 11s/epoch - 498ms/step
# Epoch 443/1200
# 22/22 - 11s - loss: 0.0265 - accuracy: 0.8957 - 11s/epoch - 496ms/step
# Epoch 444/1200
# 22/22 - 11s - loss: 0.0259 - accuracy: 0.8916 - 11s/epoch - 493ms/step
# Epoch 445/1200
# 22/22 - 10s - loss: 0.0261 - accuracy: 0.8952 - 10s/epoch - 474ms/step
# Epoch 446/1200
# 22/22 - 11s - loss: 0.0252 - accuracy: 0.8898 - 11s/epoch - 478ms/step
# Epoch 447/1200
# 22/22 - 11s - loss: 0.0253 - accuracy: 0.9003 - 11s/epoch - 493ms/step
# Epoch 448/1200
# 22/22 - 11s - loss: 0.0250 - accuracy: 0.8902 - 11s/epoch - 495ms/step
# Epoch 449/1200
# 22/22 - 11s - loss: 0.0265 - accuracy: 0.8879 - 11s/epoch - 492ms/step
# Epoch 450/1200
# 22/22 - 11s - loss: 0.0258 - accuracy: 0.8975 - 11s/epoch - 494ms/step
# Epoch 451/1200
# 22/22 - 11s - loss: 0.0252 - accuracy: 0.8925 - 11s/epoch - 493ms/step
# Epoch 452/1200
# 22/22 - 11s - loss: 0.0249 - accuracy: 0.9003 - 11s/epoch - 495ms/step
# Epoch 453/1200
# 22/22 - 11s - loss: 0.0246 - accuracy: 0.8943 - 11s/epoch - 492ms/step
# Epoch 454/1200
# 22/22 - 11s - loss: 0.0252 - accuracy: 0.8925 - 11s/epoch - 493ms/step
# Epoch 455/1200
# 22/22 - 11s - loss: 0.0256 - accuracy: 0.8833 - 11s/epoch - 495ms/step
# Epoch 456/1200
# 22/22 - 11s - loss: 0.0248 - accuracy: 0.8898 - 11s/epoch - 493ms/step
# Epoch 457/1200
# 22/22 - 10s - loss: 0.0251 - accuracy: 0.8948 - 10s/epoch - 461ms/step
# Epoch 458/1200
# 22/22 - 11s - loss: 0.0244 - accuracy: 0.8948 - 11s/epoch - 490ms/step
# Epoch 459/1200
# 22/22 - 11s - loss: 0.0239 - accuracy: 0.8980 - 11s/epoch - 498ms/step
# Epoch 460/1200
# 22/22 - 11s - loss: 0.0249 - accuracy: 0.8911 - 11s/epoch - 496ms/step
# Epoch 461/1200
# 22/22 - 11s - loss: 0.0241 - accuracy: 0.8916 - 11s/epoch - 496ms/step
# Epoch 462/1200
# 22/22 - 11s - loss: 0.0246 - accuracy: 0.8875 - 11s/epoch - 496ms/step
# Epoch 463/1200
# 22/22 - 11s - loss: 0.0242 - accuracy: 0.8962 - 11s/epoch - 497ms/step
# Epoch 464/1200
# 22/22 - 11s - loss: 0.0247 - accuracy: 0.8975 - 11s/epoch - 497ms/step
# Epoch 465/1200
# 22/22 - 11s - loss: 0.0237 - accuracy: 0.9003 - 11s/epoch - 496ms/step
# Epoch 466/1200
# 22/22 - 11s - loss: 0.0242 - accuracy: 0.8898 - 11s/epoch - 494ms/step
# Epoch 467/1200
# 22/22 - 11s - loss: 0.0239 - accuracy: 0.8920 - 11s/epoch - 497ms/step
# Epoch 468/1200
# 22/22 - 11s - loss: 0.0240 - accuracy: 0.8957 - 11s/epoch - 497ms/step
# Epoch 469/1200
# 22/22 - 10s - loss: 0.0239 - accuracy: 0.8934 - 10s/epoch - 467ms/step
# Epoch 470/1200
# 22/22 - 11s - loss: 0.0234 - accuracy: 0.9071 - 11s/epoch - 488ms/step
# Epoch 471/1200
# 22/22 - 11s - loss: 0.0229 - accuracy: 0.9048 - 11s/epoch - 497ms/step
# Epoch 472/1200
# 22/22 - 11s - loss: 0.0232 - accuracy: 0.8966 - 11s/epoch - 496ms/step
# Epoch 473/1200
# 22/22 - 11s - loss: 0.0237 - accuracy: 0.9071 - 11s/epoch - 492ms/step
# Epoch 474/1200
# 22/22 - 11s - loss: 0.0235 - accuracy: 0.8980 - 11s/epoch - 495ms/step
# Epoch 475/1200
# 22/22 - 11s - loss: 0.0228 - accuracy: 0.9067 - 11s/epoch - 494ms/step
# Epoch 476/1200
# 22/22 - 11s - loss: 0.0232 - accuracy: 0.8998 - 11s/epoch - 493ms/step
# Epoch 477/1200
# 22/22 - 11s - loss: 0.0230 - accuracy: 0.8925 - 11s/epoch - 498ms/step
# Epoch 478/1200
# 22/22 - 11s - loss: 0.0227 - accuracy: 0.9007 - 11s/epoch - 496ms/step
# Epoch 479/1200
# 22/22 - 11s - loss: 0.0228 - accuracy: 0.8916 - 11s/epoch - 496ms/step
# Epoch 480/1200
# 22/22 - 11s - loss: 0.0230 - accuracy: 0.8939 - 11s/epoch - 495ms/step
# Epoch 481/1200
# 22/22 - 11s - loss: 0.0223 - accuracy: 0.9026 - 11s/epoch - 489ms/step
# Epoch 482/1200
# 22/22 - 10s - loss: 0.0226 - accuracy: 0.8925 - 10s/epoch - 468ms/step
# Epoch 483/1200
# 22/22 - 11s - loss: 0.0218 - accuracy: 0.9035 - 11s/epoch - 492ms/step
# Epoch 484/1200
# 22/22 - 11s - loss: 0.0218 - accuracy: 0.9021 - 11s/epoch - 498ms/step
# Epoch 485/1200
# 22/22 - 11s - loss: 0.0223 - accuracy: 0.9113 - 11s/epoch - 495ms/step
# Epoch 486/1200
# 22/22 - 11s - loss: 0.0223 - accuracy: 0.9039 - 11s/epoch - 496ms/step
# Epoch 487/1200
# 22/22 - 11s - loss: 0.0217 - accuracy: 0.9007 - 11s/epoch - 494ms/step
# Epoch 488/1200
# 22/22 - 11s - loss: 0.0223 - accuracy: 0.8925 - 11s/epoch - 495ms/step
# Epoch 489/1200
# 22/22 - 11s - loss: 0.0222 - accuracy: 0.8907 - 11s/epoch - 494ms/step
# Epoch 490/1200
# 22/22 - 11s - loss: 0.0222 - accuracy: 0.8984 - 11s/epoch - 491ms/step
# Epoch 491/1200
# 22/22 - 11s - loss: 0.0216 - accuracy: 0.9044 - 11s/epoch - 495ms/step
# Epoch 492/1200
# 22/22 - 11s - loss: 0.0221 - accuracy: 0.8898 - 11s/epoch - 498ms/step
# Epoch 493/1200
# 22/22 - 11s - loss: 0.0214 - accuracy: 0.8948 - 11s/epoch - 490ms/step
# Epoch 494/1200
# 22/22 - 10s - loss: 0.0217 - accuracy: 0.8980 - 10s/epoch - 462ms/step
# Epoch 495/1200
# 22/22 - 11s - loss: 0.0213 - accuracy: 0.8998 - 11s/epoch - 492ms/step
# Epoch 496/1200
# 22/22 - 11s - loss: 0.0213 - accuracy: 0.8998 - 11s/epoch - 497ms/step
# Epoch 497/1200
# 22/22 - 11s - loss: 0.0216 - accuracy: 0.8939 - 11s/epoch - 493ms/step
# Epoch 498/1200
# 22/22 - 11s - loss: 0.0213 - accuracy: 0.8998 - 11s/epoch - 492ms/step
# Epoch 499/1200
# 22/22 - 11s - loss: 0.0217 - accuracy: 0.9058 - 11s/epoch - 492ms/step
# Epoch 500/1200
# 22/22 - 11s - loss: 0.0217 - accuracy: 0.9062 - 11s/epoch - 496ms/step
# Epoch 501/1200
# 22/22 - 11s - loss: 0.0209 - accuracy: 0.8980 - 11s/epoch - 497ms/step
# Epoch 502/1200
# 22/22 - 11s - loss: 0.0214 - accuracy: 0.8984 - 11s/epoch - 498ms/step
# Epoch 503/1200
# 22/22 - 11s - loss: 0.0215 - accuracy: 0.9108 - 11s/epoch - 498ms/step
# Epoch 504/1200
# 22/22 - 11s - loss: 0.0207 - accuracy: 0.8943 - 11s/epoch - 491ms/step
# Epoch 505/1200
# 22/22 - 11s - loss: 0.0212 - accuracy: 0.9094 - 11s/epoch - 493ms/step
# Epoch 506/1200
# 22/22 - 10s - loss: 0.0199 - accuracy: 0.8984 - 10s/epoch - 457ms/step
# Epoch 507/1200
# 22/22 - 11s - loss: 0.0209 - accuracy: 0.9053 - 11s/epoch - 488ms/step
# Epoch 508/1200
# 22/22 - 11s - loss: 0.0206 - accuracy: 0.9067 - 11s/epoch - 498ms/step
# Epoch 509/1200
# 22/22 - 11s - loss: 0.0204 - accuracy: 0.9021 - 11s/epoch - 493ms/step
# Epoch 510/1200
# 22/22 - 11s - loss: 0.0199 - accuracy: 0.9058 - 11s/epoch - 497ms/step
# Epoch 511/1200
# 22/22 - 11s - loss: 0.0203 - accuracy: 0.9003 - 11s/epoch - 495ms/step
# Epoch 512/1200
# 22/22 - 11s - loss: 0.0206 - accuracy: 0.9030 - 11s/epoch - 499ms/step
# Epoch 513/1200
# 22/22 - 11s - loss: 0.0202 - accuracy: 0.8943 - 11s/epoch - 496ms/step
# Epoch 514/1200
# 22/22 - 11s - loss: 0.0205 - accuracy: 0.9076 - 11s/epoch - 497ms/step
# Epoch 515/1200
# 22/22 - 11s - loss: 0.0200 - accuracy: 0.9039 - 11s/epoch - 499ms/step
# Epoch 516/1200
# 22/22 - 11s - loss: 0.0209 - accuracy: 0.9039 - 11s/epoch - 495ms/step
# Epoch 517/1200
# 22/22 - 11s - loss: 0.0204 - accuracy: 0.9076 - 11s/epoch - 493ms/step
# Epoch 518/1200
# 22/22 - 10s - loss: 0.0198 - accuracy: 0.9103 - 10s/epoch - 466ms/step
# Epoch 519/1200
# 22/22 - 11s - loss: 0.0198 - accuracy: 0.9076 - 11s/epoch - 493ms/step
# Epoch 520/1200
# 22/22 - 11s - loss: 0.0193 - accuracy: 0.9007 - 11s/epoch - 498ms/step
# Epoch 521/1200
# 22/22 - 11s - loss: 0.0199 - accuracy: 0.8975 - 11s/epoch - 495ms/step
# Epoch 522/1200
# 22/22 - 11s - loss: 0.0203 - accuracy: 0.8962 - 11s/epoch - 496ms/step
# Epoch 523/1200
# 22/22 - 11s - loss: 0.0199 - accuracy: 0.9103 - 11s/epoch - 497ms/step
# Epoch 524/1200
# 22/22 - 11s - loss: 0.0200 - accuracy: 0.9081 - 11s/epoch - 498ms/step
# Epoch 525/1200
# 22/22 - 11s - loss: 0.0197 - accuracy: 0.9076 - 11s/epoch - 494ms/step
# Epoch 526/1200
# 22/22 - 11s - loss: 0.0196 - accuracy: 0.9113 - 11s/epoch - 494ms/step
# Epoch 527/1200
# 22/22 - 11s - loss: 0.0199 - accuracy: 0.9071 - 11s/epoch - 495ms/step
# Epoch 528/1200
# 22/22 - 11s - loss: 0.0200 - accuracy: 0.9145 - 11s/epoch - 497ms/step
# Epoch 529/1200
# 22/22 - 11s - loss: 0.0191 - accuracy: 0.9085 - 11s/epoch - 497ms/step
# Epoch 530/1200
# 22/22 - 11s - loss: 0.0190 - accuracy: 0.9062 - 11s/epoch - 492ms/step
# Epoch 531/1200
# 22/22 - 10s - loss: 0.0195 - accuracy: 0.9062 - 10s/epoch - 473ms/step
# Epoch 532/1200
# 22/22 - 11s - loss: 0.0192 - accuracy: 0.9103 - 11s/epoch - 499ms/step
# Epoch 533/1200
# 22/22 - 11s - loss: 0.0194 - accuracy: 0.9039 - 11s/epoch - 495ms/step
# Epoch 534/1200
# 22/22 - 11s - loss: 0.0188 - accuracy: 0.8925 - 11s/epoch - 497ms/step
# Epoch 535/1200
# 22/22 - 11s - loss: 0.0193 - accuracy: 0.9126 - 11s/epoch - 500ms/step
# Epoch 536/1200
# 22/22 - 11s - loss: 0.0188 - accuracy: 0.8957 - 11s/epoch - 495ms/step
# Epoch 537/1200
# 22/22 - 11s - loss: 0.0185 - accuracy: 0.9117 - 11s/epoch - 499ms/step
# Epoch 538/1200
# 22/22 - 11s - loss: 0.0184 - accuracy: 0.9053 - 11s/epoch - 495ms/step
# Epoch 539/1200
# 22/22 - 11s - loss: 0.0185 - accuracy: 0.9145 - 11s/epoch - 497ms/step
# Epoch 540/1200
# 22/22 - 11s - loss: 0.0182 - accuracy: 0.9167 - 11s/epoch - 499ms/step
# Epoch 541/1200
# 22/22 - 11s - loss: 0.0186 - accuracy: 0.9103 - 11s/epoch - 498ms/step
# Epoch 542/1200
# 22/22 - 11s - loss: 0.0186 - accuracy: 0.9048 - 11s/epoch - 499ms/step
# Epoch 543/1200
# 22/22 - 11s - loss: 0.0186 - accuracy: 0.9053 - 11s/epoch - 499ms/step
# Epoch 544/1200
# 22/22 - 10s - loss: 0.0188 - accuracy: 0.8998 - 10s/epoch - 472ms/step
# Epoch 545/1200
# 22/22 - 11s - loss: 0.0184 - accuracy: 0.9053 - 11s/epoch - 491ms/step
# Epoch 546/1200
# 22/22 - 11s - loss: 0.0183 - accuracy: 0.9113 - 11s/epoch - 493ms/step
# Epoch 547/1200
# 22/22 - 11s - loss: 0.0180 - accuracy: 0.9085 - 11s/epoch - 495ms/step
# Epoch 548/1200
# 22/22 - 11s - loss: 0.0182 - accuracy: 0.9149 - 11s/epoch - 496ms/step
# Epoch 549/1200
# 22/22 - 11s - loss: 0.0182 - accuracy: 0.9058 - 11s/epoch - 497ms/step
# Epoch 550/1200
# 22/22 - 11s - loss: 0.0186 - accuracy: 0.9012 - 11s/epoch - 493ms/step
# Epoch 551/1200
# 22/22 - 11s - loss: 0.0179 - accuracy: 0.9044 - 11s/epoch - 495ms/step
# Epoch 552/1200
# 22/22 - 11s - loss: 0.0181 - accuracy: 0.9149 - 11s/epoch - 499ms/step
# Epoch 553/1200
# 22/22 - 11s - loss: 0.0185 - accuracy: 0.9039 - 11s/epoch - 495ms/step
# Epoch 554/1200
# 22/22 - 11s - loss: 0.0182 - accuracy: 0.9067 - 11s/epoch - 496ms/step
# Epoch 555/1200
# 22/22 - 11s - loss: 0.0182 - accuracy: 0.9103 - 11s/epoch - 497ms/step
# Epoch 556/1200
# 22/22 - 11s - loss: 0.0182 - accuracy: 0.9154 - 11s/epoch - 480ms/step
# Epoch 557/1200
# 22/22 - 11s - loss: 0.0178 - accuracy: 0.9213 - 11s/epoch - 482ms/step
# Epoch 558/1200
# 22/22 - 11s - loss: 0.0180 - accuracy: 0.9131 - 11s/epoch - 498ms/step
# Epoch 559/1200
# 22/22 - 11s - loss: 0.0185 - accuracy: 0.9067 - 11s/epoch - 499ms/step
# Epoch 560/1200
# ...
# Epoch 1128/1200
# 22/22 - 11s - loss: 0.0078 - accuracy: 0.9392 - 11s/epoch - 512ms/step
# Epoch 1129/1200
# 22/22 - 11s - loss: 0.0078 - accuracy: 0.9433 - 11s/epoch - 521ms/step
# Epoch 1130/1200
# 22/22 - 11s - loss: 0.0076 - accuracy: 0.9446 - 11s/epoch - 514ms/step
# Epoch 1131/1200
# 22/22 - 11s - loss: 0.0077 - accuracy: 0.9373 - 11s/epoch - 510ms/step
# Epoch 1132/1200
# 22/22 - 11s - loss: 0.0075 - accuracy: 0.9405 - 11s/epoch - 518ms/step
# Epoch 1133/1200
# 22/22 - 11s - loss: 0.0075 - accuracy: 0.9437 - 11s/epoch - 516ms/step
# Epoch 1134/1200
# 22/22 - 11s - loss: 0.0076 - accuracy: 0.9538 - 11s/epoch - 499ms/step
# Epoch 1135/1200
# 22/22 - 11s - loss: 0.0076 - accuracy: 0.9378 - 11s/epoch - 496ms/step
# Epoch 1136/1200
# 22/22 - 11s - loss: 0.0076 - accuracy: 0.9410 - 11s/epoch - 515ms/step
# Epoch 1137/1200
# 22/22 - 11s - loss: 0.0076 - accuracy: 0.9524 - 11s/epoch - 519ms/step
# Epoch 1138/1200
# 22/22 - 11s - loss: 0.0077 - accuracy: 0.9419 - 11s/epoch - 513ms/step
# Epoch 1139/1200
# 22/22 - 11s - loss: 0.0073 - accuracy: 0.9437 - 11s/epoch - 518ms/step
# Epoch 1140/1200
# 22/22 - 11s - loss: 0.0076 - accuracy: 0.9410 - 11s/epoch - 515ms/step
# Epoch 1141/1200
# 22/22 - 11s - loss: 0.0075 - accuracy: 0.9405 - 11s/epoch - 517ms/step
# Epoch 1142/1200
# 22/22 - 11s - loss: 0.0075 - accuracy: 0.9474 - 11s/epoch - 519ms/step
# Epoch 1143/1200
# 22/22 - 11s - loss: 0.0073 - accuracy: 0.9373 - 11s/epoch - 523ms/step
# Epoch 1144/1200
# 22/22 - 11s - loss: 0.0076 - accuracy: 0.9369 - 11s/epoch - 515ms/step
# Epoch 1145/1200
# 22/22 - 11s - loss: 0.0074 - accuracy: 0.9387 - 11s/epoch - 513ms/step
# Epoch 1146/1200
# 22/22 - 11s - loss: 0.0077 - accuracy: 0.9332 - 11s/epoch - 519ms/step
# Epoch 1147/1200
# 22/22 - 11s - loss: 0.0075 - accuracy: 0.9414 - 11s/epoch - 512ms/step
# Epoch 1148/1200
# 22/22 - 11s - loss: 0.0075 - accuracy: 0.9410 - 11s/epoch - 517ms/step
# Epoch 1149/1200
# 22/22 - 11s - loss: 0.0079 - accuracy: 0.9396 - 11s/epoch - 519ms/step
# Epoch 1150/1200
# 22/22 - 11s - loss: 0.0076 - accuracy: 0.9424 - 11s/epoch - 518ms/step
# Epoch 1151/1200
# 22/22 - 11s - loss: 0.0074 - accuracy: 0.9424 - 11s/epoch - 521ms/step
# Epoch 1152/1200
# 22/22 - 11s - loss: 0.0073 - accuracy: 0.9460 - 11s/epoch - 517ms/step
# Epoch 1153/1200
# 22/22 - 11s - loss: 0.0076 - accuracy: 0.9524 - 11s/epoch - 520ms/step
# Epoch 1154/1200
# 22/22 - 11s - loss: 0.0077 - accuracy: 0.9401 - 11s/epoch - 518ms/step
# Epoch 1155/1200
# 22/22 - 11s - loss: 0.0075 - accuracy: 0.9405 - 11s/epoch - 518ms/step
# Epoch 1156/1200
# 22/22 - 11s - loss: 0.0075 - accuracy: 0.9424 - 11s/epoch - 514ms/step
# Epoch 1157/1200
# 22/22 - 11s - loss: 0.0075 - accuracy: 0.9373 - 11s/epoch - 512ms/step
# Epoch 1158/1200
# 22/22 - 11s - loss: 0.0076 - accuracy: 0.9373 - 11s/epoch - 512ms/step
# Epoch 1159/1200
# 22/22 - 11s - loss: 0.0076 - accuracy: 0.9469 - 11s/epoch - 494ms/step
# Epoch 1160/1200
# 22/22 - 11s - loss: 0.0075 - accuracy: 0.9446 - 11s/epoch - 499ms/step
# Epoch 1161/1200
# 22/22 - 11s - loss: 0.0074 - accuracy: 0.9382 - 11s/epoch - 518ms/step
# Epoch 1162/1200
# 22/22 - 11s - loss: 0.0074 - accuracy: 0.9515 - 11s/epoch - 516ms/step
# Epoch 1163/1200
# 22/22 - 11s - loss: 0.0073 - accuracy: 0.9424 - 11s/epoch - 510ms/step
# Epoch 1164/1200
# 22/22 - 11s - loss: 0.0074 - accuracy: 0.9414 - 11s/epoch - 515ms/step
# Epoch 1165/1200
# 22/22 - 11s - loss: 0.0075 - accuracy: 0.9410 - 11s/epoch - 517ms/step
# Epoch 1166/1200
# 22/22 - 11s - loss: 0.0075 - accuracy: 0.9451 - 11s/epoch - 518ms/step
# Epoch 1167/1200
# 22/22 - 11s - loss: 0.0075 - accuracy: 0.9437 - 11s/epoch - 515ms/step
# Epoch 1168/1200
# 22/22 - 11s - loss: 0.0074 - accuracy: 0.9419 - 11s/epoch - 521ms/step
# Epoch 1169/1200
# 22/22 - 11s - loss: 0.0073 - accuracy: 0.9428 - 11s/epoch - 522ms/step
# Epoch 1170/1200
# 22/22 - 11s - loss: 0.0073 - accuracy: 0.9451 - 11s/epoch - 521ms/step
# Epoch 1171/1200
# 22/22 - 11s - loss: 0.0073 - accuracy: 0.9465 - 11s/epoch - 519ms/step
# Epoch 1172/1200
# 22/22 - 11s - loss: 0.0073 - accuracy: 0.9474 - 11s/epoch - 515ms/step
# Epoch 1173/1200
# 22/22 - 11s - loss: 0.0074 - accuracy: 0.9451 - 11s/epoch - 516ms/step
# Epoch 1174/1200
# 22/22 - 11s - loss: 0.0073 - accuracy: 0.9414 - 11s/epoch - 522ms/step
# Epoch 1175/1200
# 22/22 - 11s - loss: 0.0074 - accuracy: 0.9405 - 11s/epoch - 521ms/step
# Epoch 1176/1200
# 22/22 - 11s - loss: 0.0073 - accuracy: 0.9401 - 11s/epoch - 520ms/step
# Epoch 1177/1200
# 22/22 - 11s - loss: 0.0074 - accuracy: 0.9401 - 11s/epoch - 522ms/step
# Epoch 1178/1200
# 22/22 - 11s - loss: 0.0073 - accuracy: 0.9405 - 11s/epoch - 521ms/step
# Epoch 1179/1200
# 22/22 - 11s - loss: 0.0075 - accuracy: 0.9465 - 11s/epoch - 516ms/step
# Epoch 1180/1200
# 22/22 - 11s - loss: 0.0072 - accuracy: 0.9433 - 11s/epoch - 515ms/step
# Epoch 1181/1200
# 22/22 - 11s - loss: 0.0074 - accuracy: 0.9469 - 11s/epoch - 517ms/step
# Epoch 1182/1200
# 22/22 - 11s - loss: 0.0075 - accuracy: 0.9405 - 11s/epoch - 519ms/step
# Epoch 1183/1200
# 22/22 - 11s - loss: 0.0072 - accuracy: 0.9433 - 11s/epoch - 518ms/step
# Epoch 1184/1200
# 22/22 - 11s - loss: 0.0072 - accuracy: 0.9424 - 11s/epoch - 514ms/step
# Epoch 1185/1200
# 22/22 - 11s - loss: 0.0073 - accuracy: 0.9414 - 11s/epoch - 504ms/step
# Epoch 1186/1200
# 22/22 - 11s - loss: 0.0072 - accuracy: 0.9474 - 11s/epoch - 509ms/step
# Epoch 1187/1200
# 22/22 - 11s - loss: 0.0073 - accuracy: 0.9428 - 11s/epoch - 514ms/step
# Epoch 1188/1200
# 22/22 - 11s - loss: 0.0071 - accuracy: 0.9410 - 11s/epoch - 515ms/step
# Epoch 1189/1200
# 22/22 - 11s - loss: 0.0072 - accuracy: 0.9433 - 11s/epoch - 519ms/step
# Epoch 1190/1200
# 22/22 - 11s - loss: 0.0073 - accuracy: 0.9396 - 11s/epoch - 522ms/step
# Epoch 1191/1200
# 22/22 - 11s - loss: 0.0071 - accuracy: 0.9328 - 11s/epoch - 512ms/step
# Epoch 1192/1200
# 22/22 - 11s - loss: 0.0071 - accuracy: 0.9433 - 11s/epoch - 511ms/step
# Epoch 1193/1200
# 22/22 - 11s - loss: 0.0074 - accuracy: 0.9355 - 11s/epoch - 519ms/step
# Epoch 1194/1200
# 22/22 - 11s - loss: 0.0074 - accuracy: 0.9428 - 11s/epoch - 516ms/step
# Epoch 1195/1200
# 22/22 - 11s - loss: 0.0073 - accuracy: 0.9442 - 11s/epoch - 502ms/step
# Epoch 1196/1200
# 22/22 - 11s - loss: 0.0073 - accuracy: 0.9446 - 11s/epoch - 500ms/step
# Epoch 1197/1200
# 22/22 - 11s - loss: 0.0073 - accuracy: 0.9410 - 11s/epoch - 500ms/step
# Epoch 1198/1200
# 22/22 - 11s - loss: 0.0073 - accuracy: 0.9337 - 11s/epoch - 501ms/step
# Epoch 1199/1200
# 22/22 - 11s - loss: 0.0071 - accuracy: 0.9465 - 11s/epoch - 498ms/step
# Epoch 1200/1200
# 22/22 - 11s - loss: 0.0073 - accuracy: 0.9392 - 11s/epoch - 500ms/step
# ----------------------------------------
# Prediction vs. Ground Truth without rounding up or down
# <ipython-input-4-e169acec566b>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_input.drop(['Date'], axis=1, inplace=True)
# 1/1 [==============================] - 4s 4s/step
# Drawing Date: 06/14/2002
# Prediction:	 [ 4  8 32 36 43  1]
# Ground Truth:	 [ 4  8 32 37 43  2]
# ----------------------------------------
# 1/1 [==============================] - 0s 32ms/step
# Drawing Date: 2002-11-06 00:00:00
# Prediction:	 [ 4  5  8 32 43 51]
# Ground Truth:	 [ 5  6  9 33 44 52]
# ----------------------------------------
# 1/1 [==============================] - 0s 33ms/step
# Drawing Date: 2002-07-06 00:00:00
# Prediction:	 [14 21 26 27 41 12]
# Ground Truth:	 [14 22 27 28 42 13]
# ----------------------------------------
# <ipython-input-4-e169acec566b>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_input.drop(['Date'], axis=1, inplace=True)
# <ipython-input-4-e169acec566b>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_input.drop(['Date'], axis=1, inplace=True)
# <ipython-input-4-e169acec566b>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_input.drop(['Date'], axis=1, inplace=True)
# 1/1 [==============================] - 0s 31ms/step
# Drawing Date: 2002-04-06 00:00:00
# Prediction:	 [ 3 24 29 30 48 48]
# Ground Truth:	 [ 3 25 29 30 48 48]
# ----------------------------------------
# 1/1 [==============================] - 0s 32ms/step
# Drawing Date: 05/31/2002
# Prediction:	 [11 28 45 46 52 46]
# Ground Truth:	 [12 28 45 46 52 47]
# ----------------------------------------
# 1/1 [==============================] - 0s 32ms/step
# Drawing Date: 05/28/2002
# Prediction:	 [ 5 20 21 28 31 23]
# Ground Truth:	 [ 6 21 22 29 32 24]
# ----------------------------------------
# <ipython-input-4-e169acec566b>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_input.drop(['Date'], axis=1, inplace=True)
# <ipython-input-4-e169acec566b>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_input.drop(['Date'], axis=1, inplace=True)
# <ipython-input-4-e169acec566b>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_input.drop(['Date'], axis=1, inplace=True)
# 1/1 [==============================] - 0s 31ms/step
# Drawing Date: 05/24/2002
# Prediction:	 [ 1  3 31 43 52 34]
# Ground Truth:	 [ 2  4 32 44 52 36]
# ----------------------------------------
# 1/1 [==============================] - 0s 32ms/step
# Drawing Date: 05/21/2002
# Prediction:	 [ 3 28 39 40 44  9]
# Ground Truth:	 [ 4 28 39 41 44  9]
# ----------------------------------------
# 1/1 [==============================] - 0s 33ms/step
# Drawing Date: 05/17/2002
# Prediction:	 [15 17 24 32 47 30]
# Ground Truth:	 [15 18 25 33 47 30]
# ----------------------------------------
# ----------------------------------------
# Prediction vs. Ground Truth with rounding up
# <ipython-input-4-e169acec566b>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_input.drop(['Date'], axis=1, inplace=True)
# <ipython-input-4-e169acec566b>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_input.drop(['Date'], axis=1, inplace=True)
# <ipython-input-4-e169acec566b>:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_input.drop(['Date'], axis=1, inplace=True)
# 1/1 [==============================] - 0s 34ms/step
# Drawing Date: 06/14/2002
# Prediction:	 [ 5  9 33 37 44  2]
# Ground Truth:	 [ 4  8 32 37 43  2]
# ----------------------------------------
# 1/1 [==============================] - 0s 31ms/step
# Drawing Date: 2002-11-06 00:00:00
# Prediction:	 [ 5  6  9 33 44 52]
# Ground Truth:	 [ 5  6  9 33 44 52]
# ----------------------------------------
# 1/1 [==============================] - 0s 37ms/step
# Drawing Date: 2002-07-06 00:00:00
# Prediction:	 [15 22 27 28 42 13]
# Ground Truth:	 [14 22 27 28 42 13]
# ----------------------------------------
# <ipython-input-4-e169acec566b>:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_input.drop(['Date'], axis=1, inplace=True)
# <ipython-input-4-e169acec566b>:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_input.drop(['Date'], axis=1, inplace=True)
# <ipython-input-4-e169acec566b>:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_input.drop(['Date'], axis=1, inplace=True)
# 1/1 [==============================] - 0s 39ms/step
# Drawing Date: 2002-04-06 00:00:00
# Prediction:	 [ 4 25 30 31 49 49]
# Ground Truth:	 [ 3 25 29 30 48 48]
# ----------------------------------------
# 1/1 [==============================] - 0s 33ms/step
# Drawing Date: 05/31/2002
# Prediction:	 [12 29 46 47 53 47]
# Ground Truth:	 [12 28 45 46 52 47]
# ----------------------------------------
# 1/1 [==============================] - 0s 31ms/step
# Drawing Date: 05/28/2002
# Prediction:	 [ 6 21 22 29 32 24]
# Ground Truth:	 [ 6 21 22 29 32 24]
# ----------------------------------------
# <ipython-input-4-e169acec566b>:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_input.drop(['Date'], axis=1, inplace=True)
# <ipython-input-4-e169acec566b>:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_input.drop(['Date'], axis=1, inplace=True)
# <ipython-input-4-e169acec566b>:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_input.drop(['Date'], axis=1, inplace=True)
# 1/1 [==============================] - 0s 34ms/step
# Drawing Date: 05/24/2002
# Prediction:	 [ 2  4 32 44 53 35]
# Ground Truth:	 [ 2  4 32 44 52 36]
# ----------------------------------------
# 1/1 [==============================] - 0s 35ms/step
# Drawing Date: 05/21/2002
# Prediction:	 [ 4 29 40 41 45 10]
# Ground Truth:	 [ 4 28 39 41 44  9]
# ----------------------------------------
# 1/1 [==============================] - 0s 31ms/step
# Drawing Date: 05/17/2002
# Prediction:	 [16 18 25 33 48 31]
# Ground Truth:	 [15 18 25 33 47 30]
# ----------------------------------------
# ----------------------------------------
# Predict the Future Drawing
# <ipython-input-4-e169acec566b>:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_input.drop(['Date'], axis=1, inplace=True)
# <ipython-input-4-e169acec566b>:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_input.drop(['Date'], axis=1, inplace=True)
# 1/1 [==============================] - 0s 35ms/step
# Drawing Date: 06/02/2023
# Prediction without rounding up or down:	 [13 20 24 42 48 19]
# Prediction with rounding up           :	 [14 21 25 43 49 20]
# Prediction with rounding down         :	 [12 19 23 41 47 18]
# ----------------------------------------
